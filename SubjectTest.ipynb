# %%
from SubjectTest import*

# %%
transcript_converted
# Out:
#                  100        101        102        103        104         105  \
# Chinese    73.325000  71.476760  75.170000  71.477931  70.554138   71.477032
# English    83.230769  85.653846  85.653846  87.269231  80.807692   83.230769
# MathA      91.720930  93.674418  89.767441  84.883722  84.395350   88.302325
# MathB      99.200001  98.999987  98.960006  99.560002  98.000010  100.000000
# Chemistry  85.977777  87.711112  87.711111  90.600000  88.288889   90.600000
# Physics    93.928571  95.107143  91.964287  91.964286  93.535715   93.928572
#
#                  106        107         108        109
# Chinese    69.629399  78.844867   86.240000  78.839096
# English    83.230769  82.423077   84.038462  85.653846
# MathA      86.348838  88.790697   84.395348  80.976743
# MathB      99.000000  98.960000  100.000000  98.119999
# Chemistry  88.288889  88.866667   89.444444  92.333334
# Physics    95.107142  92.749999   90.785713  91.178570

# %%
ConvertCuttings(Cut,transcript,AllCum[109],method='FitCurve')
# Out:
# {'Chinese': 78.82241567087524,
#  'English': 85.6585580792341,
#  'MathA': 80.97746456021824,
#  'MathB': 98.77950740678727,
#  'Chemistry': 92.36624493672808,
#  'Physics': 90.90083699753833}

# %%
plot(AllScores[109]['Chinese'],fit_with_norm=True)

# %%
plot_compare('Chinese',109,108,draw_past=True)

# %%
plot_cum('Chinese',AllCuttings[109],108,draw='FitCurve',draw_past=True)
